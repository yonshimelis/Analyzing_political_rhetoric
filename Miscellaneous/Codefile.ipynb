# %% [markdown]
# # Exploring miller center data

# %%
import os 

print(os.getcwd())

os.chdir(r"C:\Users\shime\Downloads")
# Out:
# c:\Users\shime\OneDrive\Documents\GitHub\Final-Project-GroupJavaWockeez\Code

# %%
import os
import json
import pandas as pd

# Path to the folder containing all the JSON speech files
folder_path = r"C:\Users\shime\Downloads\speeches" #Change path as needed 

# Read and store all speeches
speeches = []
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as f:
            data = json.load(f)
            speeches.append({
                "title": data.get("title"),
                "date": data.get("date"),
                "url": data.get("url"),
                "transcript": data.get("transcript"),
                "president": data.get("president")
            })

# Convert to DataFrame
df = pd.DataFrame(speeches)
print(df.shape)
print(df.head())
# Out:
# (1059, 5)
#                                                title  \
# 0             December 2, 1850: First Annual Message
# 1  October 27, 1810: Proclamation-- Occupation of...
# 2  March 13, 1965: Press Conference at the White ...
# 3  September 24, 2019: Remarks at the United Nati...
# 4               January 5, 1957: Eisenhower Doctrine
#
#                         date  \
# 0  1850-12-02T13:03:58-04:56
# 1  1810-10-27T13:03:58-04:56
# 2  1965-03-13T13:00:00-05:00
# 3  2019-09-24T10:12:00-04:00
# 4  1957-01-05T13:00:00-05:00
#
#                                                  url  \
# 0  https://millercenter.org/the-presidency/presid...
# 1  https://millercenter.org/the-presidency/presid...
# 2  https://millercenter.org/the-presidency/presid...
# 3  https://millercenter.org/the-presidency/presid...
# 4  https://millercenter.org/the-presidency/presid...
#
#                                           transcript             president
# 0  Fellow-Citizens of the Senate and of the House...      Millard Fillmore
# 1  Whereas the territory south of the Mississippi...         James Madison
# 2  THE PRESIDENT. Good afternoon, ladies and gent...     Lyndon B. Johnson
# 3  PRESIDENT TRUMP:&nbsp; Thank you very much.&nb...          Donald Trump
# 4  First may I express to you my deep appreciatio...  Dwight D. Eisenhower

# %%
print(df.tail())


# Convert date column to datetime (handles timezone offsets)
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Check the most recent date
latest_date = df['date'].max()
earliest_date = df['date'].min()

print("Earliest speech date:", earliest_date)
print("Most recent speech date:", latest_date)

# See which speech that corresponds to
latest_speech = df.loc[df['date'] == latest_date]
print("\nLatest speech info:\n", latest_speech[['title', 'date', 'url']])
# Out:
#                                                   title  \
# 1054            December 3, 1860: Fourth Annual Message
# 1055  May 11, 2001: Proposal for Global Fund to Figh...
# 1056  April 14, 1938: Fireside Chat 12: On the Reces...
# 1057             December 3, 1822: Sixth Annual Message
# 1058       March 29, 1952: Jefferson-Jackson Day Dinner
#
#                            date  \
# 1054  1860-12-03T13:03:58-04:56
# 1055  2001-05-11T12:10:00-04:00
# 1056  1938-04-14T13:00:00-05:00
# 1057  1822-12-03T13:03:58-04:56
# 1058  1952-03-29T13:00:00-05:00
#
#                                                     url  \
# 1054  https://millercenter.org/the-presidency/presid...
# 1055  https://millercenter.org/the-presidency/presid...
# 1056  https://millercenter.org/the-presidency/presid...
# 1057  https://millercenter.org/the-presidency/presid...
# 1058  https://millercenter.org/the-presidency/presid...
#
#                                              transcript              president
# 1054  Fellow-Citizens of the Senate and House of Rep...         James Buchanan
# 1055  It is my honor to welcome our friend, the Pres...         George W. Bush
# 1056  Five months have gone by since I last spoke to...  Franklin D. Roosevelt
# 1057  Fellow citizens of the Senate and House of Rep...           James Monroe
# 1058  Mr. Chairman, Mr. Vice President, Mr. Speaker,...        Harry S. Truman
# Earliest speech date: 1789-04-30 13:03:58-04:56
# Most recent speech date: 2025-09-30 10:00:00-04:00
#
# Latest speech info:
#                                                 title  \
# 304  September 30, 2025: Remarks to Military Leaders
#
#                           date   url
# 304  2025-09-30 10:00:00-04:00  None
# C:\Users\shime\AppData\Local\Temp\ipykernel_42544\2355718660.py:5: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %% [markdown]
# ## Add features

# %%
#Make copy of df to keep original intact
df_raw = df.copy()

'''From this point on we will manipulate df and keep df_raw as original'''


#Check df again
print(df.columns)

#Check presidents in dataset
print(df['president'].unique())
print(len(df['president'].unique()))


#Add party affiliation
party_affiliation = { "Donald Trump": "Republican",
                        "Joe Biden": "Democrat",
                        "Barack Obama": "Democrat",
                        "George W. Bush": "Republican",
                        "Bill Clinton": "Democrat",
                        "George H. W. Bush": "Republican",
                        "Ronald Reagan": "Republican",
                        "Jimmy Carter": "Democrat",
                        "Gerald Ford": "Republican",
                        "Richard M. Nixon": "Republican",
                        "Lyndon B. Johnson": "Democrat",
                        "John F. Kennedy": "Democrat",
                        "Dwight D. Eisenhower": "Republican",
                        "Harry S. Truman": "Democrat",
                        "Franklin D. Roosevelt": "Democrat",
                        "Herbert Hoover": "Republican", 
                        "Calvin Coolidge": "Republican",
                        "Warren G. Harding": "Republican",
                        "Woodrow Wilson": "Democrat",
                        "William Taft": "Republican",
                        "Theodore Roosevelt": "Republican",
                        "William McKinley": "Republican",
                        "Grover Cleveland": "Democrat",
                        "Benjamin Harrison": "Republican",
                        "Chester A. Arthur": "Republican",
                        "James A. Garfield": "Republican",
                        "Rutherford B. Hayes": "Republican",
                        "Ulysses S. Grant": "Republican",
                        "Andrew Johnson": "Democrat",
                        "Abraham Lincoln": "Republican",
                        "James Buchanan": "Democrat",
                        "Franklin Pierce": "Democrat",
                        "Millard Fillmore": "Whig",
                        "Zachary Taylor": "Whig",
                        "James K. Polk": "Democrat",
                        "John Tyler": "Whig",
                        "William Harrison": "Whig",
                        "Martin Van Buren": "Democrat",
                        "Andrew Jackson": "Democrat",
                        "John Quincy Adams": "National Republican",
                        "James Monroe": "Democrat-Republican",
                        "James Madison": "Democrat-Republican",
                        "Thomas Jefferson": "Democrat-Republican",
                        "John Adams": "Federalist",
                        "George Washington": "Federalist"
                        }

#Check if we have all presidents listed
print(len(party_affiliation))

#Map party affiliation to df
df['party'] = df['president'].map(party_affiliation)

#Check if it correctly mapped
print(df[['president', 'party']].drop_duplicates().sort_values(by='president'))


'''Prior to the two party system we know, there were other parties such as Whig, Federalist, National Republican, and Democrat-Republican. We will keep these as is for now.'''
# Out:
# Index(['title', 'date', 'url', 'transcript', 'president', 'party'], dtype='object')
# ['Millard Fillmore' 'James Madison' 'Lyndon B. Johnson' 'Donald Trump'
#  'Dwight D. Eisenhower' 'Barack Obama' 'Grover Cleveland' 'John Tyler'
#  'John Quincy Adams' 'Ronald Reagan' 'Chester A. Arthur' 'George W. Bush'
#  'Ulysses S. Grant' 'John F. Kennedy' 'Martin Van Buren' 'Bill Clinton'
#  'Herbert Hoover' 'Andrew Johnson' 'Thomas Jefferson' 'Woodrow Wilson'
#  'William McKinley' 'Abraham Lincoln' 'Zachary Taylor' 'James Buchanan'
#  'James K. Polk' 'Franklin D. Roosevelt' 'Gerald Ford'
#  'Rutherford B. Hayes' 'Andrew Jackson' 'Joe Biden' 'Theodore Roosevelt'
#  'Calvin Coolidge' 'George Washington' 'Jimmy Carter' 'William Taft'
#  'George H. W. Bush' 'Benjamin Harrison' 'Harry S. Truman'
#  'Franklin Pierce' 'John Adams' 'Richard M. Nixon' 'James Monroe'
#  'Warren G. Harding' 'James A. Garfield' 'William Harrison']
# 45
# 45
#                  president                party
# 39         Abraham Lincoln           Republican
# 59          Andrew Jackson             Democrat
# 31          Andrew Johnson             Democrat
# 5             Barack Obama             Democrat
# 130      Benjamin Harrison           Republican
# 27            Bill Clinton             Democrat
# 96         Calvin Coolidge           Republican
# 11       Chester A. Arthur           Republican
# 3             Donald Trump           Republican
# 4     Dwight D. Eisenhower           Republican
# 49   Franklin D. Roosevelt             Democrat
# 145        Franklin Pierce             Democrat
# 120      George H. W. Bush           Republican
# 14          George W. Bush           Republican
# 104      George Washington           Federalist
# 54             Gerald Ford           Republican
# 7         Grover Cleveland             Democrat
# 137        Harry S. Truman             Democrat
# 28          Herbert Hoover           Republican
# 686      James A. Garfield           Republican
# 45          James Buchanan             Democrat
# 46           James K. Polk             Democrat
# 1            James Madison  Democrat-Republican
# 258           James Monroe  Democrat-Republican
# 113           Jimmy Carter             Democrat
# 70               Joe Biden             Democrat
# 155             John Adams           Federalist
# 18         John F. Kennedy             Democrat
# 9        John Quincy Adams  National Republican
# 8               John Tyler                 Whig
# 2        Lyndon B. Johnson             Democrat
# 22        Martin Van Buren             Democrat
# 0         Millard Fillmore                 Whig
# 170       Richard M. Nixon           Republican
# 10           Ronald Reagan           Republican
# 55     Rutherford B. Hayes           Republican
# 83      Theodore Roosevelt           Republican
# 34        Thomas Jefferson  Democrat-Republican
# 17        Ulysses S. Grant           Republican
# 294      Warren G. Harding           Republican
# 855       William Harrison                 Whig
# 38        William McKinley           Republican
# 114           William Taft           Republican
# 35          Woodrow Wilson             Democrat
# 41          Zachary Taylor                 Whig

# %%
#Check counts of speeches by president
print(df['president'].value_counts())

'''We can see that some presidents have very few speeches, especially those prior to the 20th century. This may affect our analysis later on, so we should keep this in mind.'''
# Out:
# president
# Lyndon B. Johnson        71
# Ronald Reagan            60
# Barack Obama             51
# Donald Trump             50
# Franklin D. Roosevelt    49
# John F. Kennedy          45
# George W. Bush           40
# Bill Clinton             39
# Woodrow Wilson           33
# Ulysses S. Grant         32
# Grover Cleveland         32
# Andrew Johnson           31
# Herbert Hoover           30
# Joe Biden                28
# Andrew Jackson           26
# James K. Polk            25
# Thomas Jefferson         24
# George H. W. Bush        23
# Richard M. Nixon         23
# Jimmy Carter             22
# James Madison            22
# Theodore Roosevelt       22
# George Washington        21
# John Tyler               19
# Harry S. Truman          19
# Warren G. Harding        18
# Benjamin Harrison        16
# Rutherford B. Hayes      16
# Dwight D. Eisenhower     15
# Abraham Lincoln          15
# Franklin Pierce          15
# James Buchanan           14
# William McKinley         14
# Gerald Ford              14
# William Taft             12
# Calvin Coolidge          12
# Chester A. Arthur        11
# James Monroe             10
# Martin Van Buren         10
# John Adams                9
# John Quincy Adams         8
# Millard Fillmore          7
# Zachary Taylor            4
# James A. Garfield         1
# William Harrison          1
# Name: count, dtype: int64

# %%
#Add term dates column
def term_limit(president):
    term_limits = {
        "Donald Trump": ("2017-01-20", "2021-01-20"),
        "Joe Biden": ("2021-01-20", "2025-01-20"),
        "Barack Obama": ("2009-01-20", "2017-01-20"),
        "George W. Bush": ("2001-01-20", "2009-01-20"),
        "Bill Clinton": ("1993-01-20", "2001-01-20"),
        "George H. W. Bush": ("1989-01-20", "1993-01-20"),
        "Ronald Reagan": ("1981-01-20", "1989-01-20"),
        "Jimmy Carter": ("1977-01-20", "1981-01-20"),
        "Gerald Ford": ("1974-08-09", "1977-01-20"),
        "Richard M. Nixon": ("1969-01-20", "1974-08-09"),
        "Lyndon B. Johnson": ("1963-11-22", "1969-01-20"),
        "John F. Kennedy": ("1961-01-20", "1963-11-22"),
        "Dwight D. Eisenhower": ("1953-01-20", "1961-01-20"),
        "Harry S. Truman": ("1945-04-12", "1953-01-20"),
        "Franklin D. Roosevelt": ("1933-03-04", "1945-04-12"),
        "Herbert Hoover": ("1929-03-04", "1933-03-04"),
        "Calvin Coolidge": ("1923-08-02", "1929-03-04"),
        "Warren G. Harding": ("1921-03-04", "1923-08-02"),
        "Woodrow Wilson": ("1913-03-04", "1921-03-04"),
        "William Taft": ("1909-03-04", "1913-03-04"),
        "Theodore Roosevelt": ("1901-09-14", "1909-03-04"),
        "William McKinley": ("1897-03-04", "1901-09-14"),
        "Grover Cleveland": ("1893-03-04", "1897-03-04"),
        "Benjamin Harrison": ("1889-03-04", "1893-03-04"),
        "Chester A. Arthur": ("1881-09-19", "1885-03-04"),
        "James A. Garfield": ("1881-03-04", "1881-09-19"),
        "Rutherford B. Hayes": ("1877-03-04", "1881-03-04"),
        "Ulysses S. Grant": ("1869-03-04", "1877-03-04"),
        "Andrew Johnson": ("1865-04-15", "1869-03-04"),
        "Abraham Lincoln": ("1861-03-04", "1865-04-15"),
        "James Buchanan": ("1857-03-04", "1861-03-04"),
        "Franklin Pierce": ("1853-03-04", "1857-03-04"),
        "Millard Fillmore": ("1850-07-09", "1853-03-04"),
        "Zachary Taylor": ("1849-03-04", "1850-07-09"),
        "James K. Polk": ("1845-03-04", "1849-03-04"),
        "John Tyler": ("1841-04-04", "1845-03-04"),
        "William Harrison": ("1841-03-04", "1841-04-04"),
        "Martin Van Buren": ("1837-03-04", "1841-03-04"),
        "Andrew Jackson": ("1829-03-04", "1837-03-04"),
        "John Quincy Adams": ("1825-03-04", "1829-03-04"),
        "James Monroe": ("1817-03-04", "1825-03-04"),
        "James Madison": ("1809-03-04", "1817-03-04"),
        "Thomas Jefferson": ("1801-03-04", "1809-03-04"),
        "John Adams": ("1797-03-04", "1801-03-04"),
        "George Washington": ("1789-04-30", "1797-03-04")
    }
    return term_limits.get(president, (None, None))

#Apply terms to df
df['term_start'], df['term_end'] = zip(*df['president'].apply(term_limit))

#Check if it correctly mapped
print(df[['president', 'term_start', 'term_end']].drop_duplicates().sort_values(by='president'))

#Look at df again
print(df.head())
# Out:
#                  president  term_start    term_end
# 39         Abraham Lincoln  1861-03-04  1865-04-15
# 59          Andrew Jackson  1829-03-04  1837-03-04
# 31          Andrew Johnson  1865-04-15  1869-03-04
# 5             Barack Obama  2009-01-20  2017-01-20
# 130      Benjamin Harrison  1889-03-04  1893-03-04
# 27            Bill Clinton  1993-01-20  2001-01-20
# 96         Calvin Coolidge  1923-08-02  1929-03-04
# 11       Chester A. Arthur  1881-09-19  1885-03-04
# 3             Donald Trump  2017-01-20  2021-01-20
# 4     Dwight D. Eisenhower  1953-01-20  1961-01-20
# 49   Franklin D. Roosevelt  1933-03-04  1945-04-12
# 145        Franklin Pierce  1853-03-04  1857-03-04
# 120      George H. W. Bush  1989-01-20  1993-01-20
# 14          George W. Bush  2001-01-20  2009-01-20
# 104      George Washington  1789-04-30  1797-03-04
# 54             Gerald Ford  1974-08-09  1977-01-20
# 7         Grover Cleveland  1893-03-04  1897-03-04
# 137        Harry S. Truman  1945-04-12  1953-01-20
# 28          Herbert Hoover  1929-03-04  1933-03-04
# 686      James A. Garfield  1881-03-04  1881-09-19
# 45          James Buchanan  1857-03-04  1861-03-04
# 46           James K. Polk  1845-03-04  1849-03-04
# 1            James Madison  1809-03-04  1817-03-04
# 258           James Monroe  1817-03-04  1825-03-04
# 113           Jimmy Carter  1977-01-20  1981-01-20
# 70               Joe Biden  2021-01-20        None
# 155             John Adams  1797-03-04  1801-03-04
# 18         John F. Kennedy  1961-01-20  1963-11-22
# 9        John Quincy Adams  1825-03-04  1829-03-04
# 8               John Tyler  1841-04-04  1845-03-04
# 2        Lyndon B. Johnson  1963-11-22  1969-01-20
# 22        Martin Van Buren  1837-03-04  1841-03-04
# 0         Millard Fillmore  1850-07-09  1853-03-04
# 170       Richard M. Nixon  1969-01-20  1974-08-09
# 10           Ronald Reagan  1981-01-20  1989-01-20
# 55     Rutherford B. Hayes  1877-03-04  1881-03-04
# 83      Theodore Roosevelt  1901-09-14  1909-03-04
# 34        Thomas Jefferson  1801-03-04  1809-03-04
# 17        Ulysses S. Grant  1869-03-04  1877-03-04
# 294      Warren G. Harding  1921-03-04  1923-08-02
# 855       William Harrison  1841-03-04  1841-04-04
# 38        William McKinley  1897-03-04  1901-09-14
# 114           William Taft  1909-03-04  1913-03-04
# 35          Woodrow Wilson  1913-03-04  1921-03-04
# 41          Zachary Taylor  1849-03-04  1850-07-09
#                                                title  \
# 0             December 2, 1850: First Annual Message
# 1  October 27, 1810: Proclamation-- Occupation of...
# 2  March 13, 1965: Press Conference at the White ...
# 3  September 24, 2019: Remarks at the United Nati...
# 4               January 5, 1957: Eisenhower Doctrine
#
#                         date  \
# 0  1850-12-02 13:03:58-04:56
# 1  1810-10-27 13:03:58-04:56
# 2  1965-03-13 13:00:00-05:00
# 3  2019-09-24 10:12:00-04:00
# 4  1957-01-05 13:00:00-05:00
#
#                                                  url  \
# 0  https://millercenter.org/the-presidency/presid...
# 1  https://millercenter.org/the-presidency/presid...
# 2  https://millercenter.org/the-presidency/presid...
# 3  https://millercenter.org/the-presidency/presid...
# 4  https://millercenter.org/the-presidency/presid...
#
#                                           transcript             president  \
# 0  Fellow-Citizens of the Senate and of the House...      Millard Fillmore
# 1  Whereas the territory south of the Mississippi...         James Madison
# 2  THE PRESIDENT. Good afternoon, ladies and gent...     Lyndon B. Johnson
# 3  PRESIDENT TRUMP:&nbsp; Thank you very much.&nb...          Donald Trump
# 4  First may I express to you my deep appreciatio...  Dwight D. Eisenhower
#
#                  party  term_start    term_end
# 0                 Whig  1850-07-09  1853-03-04
# 1  Democrat-Republican  1809-03-04  1817-03-04
# 2             Democrat  1963-11-22  1969-01-20
# 3           Republican  2017-01-20  2021-01-20
# 4           Republican  1953-01-20  1961-01-20

# %% [markdown]
# # Begin preprocessing text

# %%
#Preprocess text

#Import necessary libraries
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords') # Download if needed
from nltk.tokenize import word_tokenize
nltk.download('punkt') #Download if needed
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet') #Download if needed

#Define stopwords
stopwords = set(stopwords.words('english'))

#Create function to preprocess text
def preprocess(text): 
    text = text.lower()  # Lowercase
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)  # Remove URLs
    text = re.sub(r'&[a-z]+;', ' ', text)  # Remove HTML entities
    text = re.sub(r"[^a-z\s']", ' ', text)  # Remove punctuation and special characters
    text = re.sub(r'\s+', ' ',text).strip()  # Remove extra whitespace
    text = re.sub (r'\d+', '', text)  # Remove numbers
    tokens = word_tokenize(text)  # Tokenization
    tokens = [word for word in tokens if word not in stopwords]  # Remove stopwords
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatization
    return ' '.join(tokens)  # Join tokens back to string

#Apply to text 
df['cleaned_transcript'] = df['transcript'].apply(preprocess)

#Check df 
print(df[['transcript', 'cleaned_transcript']].head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shime\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shime\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shime\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                           transcript  \
# 0  Fellow-Citizens of the Senate and of the House...
# 1  Whereas the territory south of the Mississippi...
# 2  THE PRESIDENT. Good afternoon, ladies and gent...
# 3  PRESIDENT TRUMP:&nbsp; Thank you very much.&nb...
# 4  First may I express to you my deep appreciatio...
#
#                                   cleaned_transcript
# 0  fellow citizen senate house representative sud...
# 1  whereas territory south mississippi territory ...
# 2  president good afternoon lady gentleman march ...
# 3  president trump thank much mr president mr sec...
# 4  first may express deep appreciation courtesy g...

# %%
# Topic analysis will be done in next steps
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import NMF
from sklearn.decomposition import LatentDirichletAllocation

#Vectorization and fitting
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
X = vectorizer.fit_transform(df['cleaned_transcript'])

# Fit NMF model
num_topics = 10  # Define number of topics
nmf_model = NMF(n_components=num_topics, random_state=42)
nmf_model.fit(X)

# Display topics
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx + 1}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

#Use the function to display topics
no_top_words = 10
tfidf_feature_names = vectorizer.get_feature_names_out()
display_topics(nmf_model, tfidf_feature_names, no_top_words)
# Out:
# Topic 1:
# government | congress | year | public | country | treasury | present | subject | department | service
#
# Topic 2:
# br | people | american | war | shall | president | day | time | new | work
#
# Topic 3:
# world | nation | peace | war | soviet | people | freedom | american | america | united
#
# Topic 4:
# applause | thank | laughter | job | going | want | america | know | got | people
#
# Topic 5:
# state | united | treaty | territory | person | law | proclamation | said | act | shall
#
# Topic 6:
# span | class | program | world | military | people | federal | year | economic | strong
#
# Topic 7:
# president | mr | think | going | vietnam | people | know | viet | want | nam
#
# Topic 8:
# american | year | tax | america | job | people | ve | child | tonight | new
#
# Topic 9:
# constitution | government | state | power | law | shall | people | public | right | duty
#
# Topic 10:
# iraq | iraqi | terrorist | saddam | al | afghanistan | qaeda | regime | america | troop

# %%
#Repeat but with LDA 

#Vectorization and fitting for LDA
vectorizer_lda = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
X_lda = vectorizer_lda.fit_transform(df['cleaned_transcript'])

# Fit LDA model
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_model.fit(X_lda)

# Display LDA topics
display_topics(lda_model, vectorizer_lda.get_feature_names_out(), no_top_words)
# Out:
# Topic 1:
# br | american | year | people | america | new | nation | world | time | work
#
# Topic 2:
# class | span | america | american | year | applause | world | people | new | nation
#
# Topic 3:
# people | going | president | want | know | thank | country | think | said | like
#
# Topic 4:
# state | government | united | congress | year | country | public | great | power | time
#
# Topic 5:
# br | united | panama | state | treaty | canal | government | republic | cuba | mr
#
# Topic 6:
# president | mr | think | strong | people | year | ve | question | country | say
#
# Topic 7:
# world | nation | united | people | peace | state | war | american | force | country
#
# Topic 8:
# br | nation | people | war | world | peace | men | government | great | right
#
# Topic 9:
# state | br | united | law | constitution | shall | act | president | power | congress
#
# Topic 10:
# government | law | country | public | state | people | congress | business | national | shall
