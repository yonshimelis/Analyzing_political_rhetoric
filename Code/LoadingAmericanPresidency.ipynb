# %% [markdown]
# # Exploring American Presidency Project Kaggle

# %%
import os 


os.chdir(r"C:\Users\shime\Downloads")

print(os.getcwd())
# Out:
# C:\Users\shime\Downloads

# %%
import json

file_path = r"C:\Users\shime\Downloads\presidency.json"

with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Basic structure inspection
print(type(data))
if isinstance(data, dict):
    print("Top-level keys:", list(data.keys())[:10])
elif isinstance(data, list):
    print("Length:", len(data))
    print("Sample keys in first item:", data[0].keys())
else:
    print("Unknown type:", type(data))
# Out:
# <class 'dict'>
# Top-level keys: ['Andrew Johnson', 'Millard Fillmore', 'Calvin Coolidge', 'James Monroe', 'Zachary Taylor', 'Franklin D. Roosevelt', 'Warren G. Harding', 'Theodore Roosevelt', 'James A. Garfield', 'George Washington']

# %%
import json
import pandas as pd

file_path = r"C:\Users\shime\Downloads\presidency.json"

# Load JSON
with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

rows = []

# Loop over presidents
for president, categories in data.items():
    # Each president has multiple types (Written, Debates, etc.)
    for category, speeches in categories.items():
        if isinstance(speeches, list):  # Only proceed if it’s a list of speeches
            for speech in speeches:
                rows.append({
                    "President": president,
                    "Category": category,
                    "Title": speech.get("title") or speech.get("document", ""),
                    "Date": speech.get("date"),
                    "Text": (
                        speech.get("text")
                        or speech.get("speech")
                        or speech.get("content")
                        or ""
                    )
                })

# Convert to DataFrame
df_presidency = pd.DataFrame(rows)
print(df_presidency.shape)
print(df_presidency.head())
# Out:
# (58612, 5)
#         President Category            Title  Date  \
# 0  Andrew Johnson  Written  Special Message  None
# 1  Andrew Johnson  Written  Special Message  None
# 2  Andrew Johnson  Written  Special Message  None
# 3  Andrew Johnson  Written  Special Message  None
# 4  Andrew Johnson  Written  Special Message  None
#
#                                                 Text
# 0  To the Senate and House of Representatives of ...
# 1  To the Senate of the United States: In answer ...
# 2  To the House of Representatives: In answer to ...
# 3  To the Senate and House of Representatives of ...
# 4  To the Senate of the United States: In reply t...

# %%
import json

path = r"C:\Users\shime\Downloads\presidency.json"

with open(path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# print top-level keys (presidents)
print("Top-level keys:", list(data.keys())[:10])

# Peek at one president's structure
pres = list(data.keys())[0]
print(f"\nFirst president: {pres}")
print("Keys under this president:", list(data[pres].keys()))

# Peek at first few items under one category
category = list(data[pres].keys())[0]
print(f"\nCategory: {category}, # of items:", len(data[pres][category]))
if len(data[pres][category]) > 0:
    print("\nSample item keys:")
    print(list(data[pres][category][0].keys()))
    print("\nSample item snippet:")
    print(json.dumps(data[pres][category][0], indent=2)[:1000])
# Out:
# Top-level keys: ['Andrew Johnson', 'Millard Fillmore', 'Calvin Coolidge', 'James Monroe', 'Zachary Taylor', 'Franklin D. Roosevelt', 'Warren G. Harding', 'Theodore Roosevelt', 'James A. Garfield', 'George Washington']
#
# First president: Andrew Johnson
# Keys under this president: ['OMB', 'E.O.P.', 'Party Platforms', 'Debates', 'Written', 'Oral']
#
# Category: OMB, # of items: 0

# %%
# Find the first non-empty category for any president
for pres, categories in data.items():
    for cat, docs in categories.items():
        if isinstance(docs, list) and len(docs) > 0:
            print(f"Found non-empty: {pres} → {cat} ({len(docs)} items)")
            print("Sample document keys:", list(docs[0].keys()))
            print("\nSample document (first 500 chars):")
            print(json.dumps(docs[0], indent=2)[:500])
            raise SystemExit
# Out:
# Found non-empty: Andrew Johnson → Written (504 items)
# Sample document keys: ['category', 'subcategory', 'title', 'pid', 'content', 'document_date']
#
# Sample document (first 500 chars):
# {
#   "category": "Messages",
#   "subcategory": "to Congress",
#   "title": "Special Message",
#   "pid": 72363,
#   "content": "To the Senate and House of Representatives of the United States: I transmit a report of this date from the Secretary of State, and the papers referred to therein, concerning the Universal Exposition to be held at Paris in the year 1867, in which the United States have been invited by the Government of France to take part. I commend the subject to your early and favorable consid
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\shime\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3557: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
# ...

# %%
import pandas as pd
import json

path = r"C:\Users\shime\Downloads\presidency.json"

# Load the JSON file (assuming it's in your current working directory)
with open(path, "r") as f:
    data = json.load(f)

rows = []
for president, categories in data.items():
    for category, docs in categories.items():
        if isinstance(docs, list) and len(docs) > 0:
            for doc in docs:
                rows.append({
                    "President": president,
                    "Category": category,
                    "DocCategory": doc.get("category"),
                    "Subcategory": doc.get("subcategory"),
                    "Title": doc.get("title"),
                    "Date": doc.get("document_date"),
                    "Text": doc.get("content")
                })

# Create DataFrame
df = pd.DataFrame(rows)
print(df.shape)
print(df.head(3))
# Out:
# (58612, 7)
#         President Category DocCategory  Subcategory            Title  \
# 0  Andrew Johnson  Written    Messages  to Congress  Special Message
# 1  Andrew Johnson  Written    Messages  to Congress  Special Message
# 2  Andrew Johnson  Written    Messages  to Congress  Special Message
#
#                   Date                                               Text
# 0  1865-12-11 00:00:00  To the Senate and House of Representatives of ...
# 1  1865-12-13 00:00:00  To the Senate of the United States: In answer ...
# 2  1865-12-14 00:00:00  To the House of Representatives: In answer to ...

# %%
print(df.columns)

print(df['President'].value_counts())

#Check for Trump speeches
print('Trump' in df['President'].values)
print('Biden' in df['President'].values)
#Trump not in dataset
# Out:
# Index(['President', 'Category', 'DocCategory', 'Subcategory', 'Title', 'Date',
#        'Text'],
#       dtype='object')
# President
# William J. Clinton        7941
# George W. Bush            6473
# Barack Obama              6142
# Ronald Reagan             5473
# Lyndon B. Johnson         3440
# George Bush               3322
# Harry S. Truman           3226
# Jimmy Carter              2925
# Dwight D. Eisenhower      2877
# Richard Nixon             2728
# Franklin D. Roosevelt     2233
# Gerald R. Ford            2068
# John F. Kennedy           1597
# Herbert Hoover            1302
# Theodore Roosevelt         513
# Andrew Johnson             505
# Ulysses S. Grant           495
# Chester A. Arthur          464
# Abraham Lincoln            427
# Andrew Jackson             374
# Woodrow Wilson             351
# Benjamin Harrison          330
# Grover Cleveland           307
# Franklin Pierce            299
# James Monroe               277
# William McKinley           253
# ...

# %%
print(len(df['President'].unique()))
# Out:
# 43

# %%
print(df.head())

print(df['Category'].value_counts())
# Out:
#         President Category DocCategory  Subcategory            Title  \
# 0  Andrew Johnson  Written    Messages  to Congress  Special Message
# 1  Andrew Johnson  Written    Messages  to Congress  Special Message
# 2  Andrew Johnson  Written    Messages  to Congress  Special Message
# 3  Andrew Johnson  Written    Messages  to Congress  Special Message
# 4  Andrew Johnson  Written    Messages  to Congress  Special Message
#
#                   Date                                               Text
# 0  1865-12-11 00:00:00  To the Senate and House of Representatives of ...
# 1  1865-12-13 00:00:00  To the Senate of the United States: In answer ...
# 2  1865-12-14 00:00:00  To the House of Representatives: In answer to ...
# 3  1865-12-18 00:00:00  To the Senate and House of Representatives of ...
# 4  1865-12-18 00:00:00  To the Senate of the United States: In reply t...
# Category
# Written    38266
# Oral       20329
# Debates       17
# Name: count, dtype: int64

# %%
df[df['Category'] == 'Oral']['President'].value_counts()
# Out:
# President
# George W. Bush            2922
# William J. Clinton        2919
# Barack Obama              2545
# Ronald Reagan             2241
# Lyndon B. Johnson         1445
# George Bush               1437
# Jimmy Carter               984
# Gerald R. Ford             962
# Harry S. Truman            917
# Dwight D. Eisenhower       908
# Richard Nixon              873
# John F. Kennedy            711
# Franklin D. Roosevelt      675
# Herbert Hoover             410
# Woodrow Wilson             162
# Calvin Coolidge             81
# Theodore Roosevelt          52
# Abraham Lincoln             17
# Benjamin Harrison           16
# George Washington           10
# Warren G. Harding            6
# John Adams                   5
# William McKinley             4
# William Howard Taft          3
# James Madison                2
# James Monroe                 2
# Ulysses S. Grant             2
# Thomas Jefferson             2
# Andrew Jackson               2
# ...

# %%
# %pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 1.9 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
SEARCH_URL = "https://www.presidency.ucsb.edu/advanced-search?page={}&field-president={}"

HEADERS = {"User-Agent": "Mozilla/5.0"}

PRESIDENTS = [
    "Joe Biden",
    "Donald Trump",
    "Barack Obama",
    "George W. Bush",
    "Bill Clinton",
    "George Bush",
    "Ronald Reagan",
    "Jimmy Carter",
    "Gerald Ford",
    "Richard Nixon",
    "Lyndon Johnson",
    "John Kennedy",
    "Dwight Eisenhower",
    "Harry Truman",
    "Franklin Roosevelt",
    "Herbert Hoover",
    "Calvin Coolidge",
    "Warren Harding",
    "Woodrow Wilson",
    "William Howard Taft",
    "Theodore Roosevelt",
    "William McKinley",
    "Grover Cleveland",
    "Benjamin Harrison",
    "Chester Arthur",
    "James Garfield",
    "Rutherford Hayes",
    "Ulysses Grant",
    "Andrew Johnson",
    "Abraham Lincoln",
    "James Buchanan",
    "Franklin Pierce",
    "Millard Fillmore",
    "Zachary Taylor",
    "James K. Polk",
    "John Tyler",
    "William Henry Harrison",
    "Martin Van Buren",
    "Andrew Jackson",
    "John Quincy Adams",
    "James Monroe",
    "James Madison",
    "Thomas Jefferson",
    "John Adams",
    "George Washington"
]

def get_document_links(president):
    links = []
    page = 0

    while True:
        url = SEARCH_URL.format(page, president.replace(" ", "+"))
        r = requests.get(url, headers=HEADERS)
        soup = BeautifulSoup(r.text, "html.parser")

        docs = soup.select("div.views-row a")
        if not docs:
            break

        for d in docs:
            href = d.get("href")
            if href and "/documents/" in href:
                links.append(BASE + href)

        page += 1
        time.sleep(0.3)

    return links


def scrape_document(url):
    r = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(r.text, "html.parser")

    title = soup.find("h1").get_text(strip=True)
    date = soup.find("span", class_="date-display-single")
    date = date.get_text(strip=True) if date else None

    cat = soup.find("div", class_="field-docs-subjects")
    cat = cat.get_text(" ", strip=True) if cat else None

    transcript = soup.find("div", class_="field-docs-content")
    transcript = transcript.get_text("\n", strip=True) if transcript else ""

    president = soup.find("div", class_="president")
    president = president.get_text(strip=True) if president else None

    return {
        "president": president,
        "date": date,
        "title": title,
        "category": cat,
        "url": url,
        "transcript": transcript
    }


# --- MASTER SCRAPE ---
rows = []

for pres in PRESIDENTS:
    print(f"\nScraping all documents for {pres}...")
    links = get_document_links(pres)
    print(f"Found {len(links)} documents.")

    for link in tqdm(links):
        try:
            data = scrape_document(link)
            rows.append(data)
        except Exception as e:
            print("Error:", link, e)
        time.sleep(0.3)

df = pd.DataFrame(rows)
df.to_csv("american_presidency_project_full.csv", index=False)
df

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from tqdm import tqdm

BASE = "https://www.presidency.ucsb.edu"

# --- MANUAL president name → ID mapping (partial; add more) ---
PRESIDENT_IDS = {
    "Joe Biden": "35300",
    "Donald J. Trump": "33002",
    "Barack Obama": "27051",
    "George W. Bush": "23001",
    "Bill Clinton": "18000",
    # add older presidents...
}

def get_document_links(pres_id, max_pages=300):
    links = []
    for page in range(max_pages):
        url = f"{BASE}/advanced-search?field-president={pres_id}&items_per_page=100&page={page}"
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")

        # adjust selector to new structure
        rows = soup.select("div.view-content .views-row a")
        if not rows:
            break

        for a in rows:
            href = a.get("href", "")
            if href.startswith("/documents/"):
                links.append(BASE + href)

        time.sleep(0.2)
    return links

def scrape_document(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    title = soup.find("h1").get_text(strip=True) if soup.find("h1") else None

    date_tag = soup.find("span", class_="date-display-single")
    date = date_tag.get_text(strip=True) if date_tag else None

    content_div = soup.find("div", class_="field-docs-content")
    transcript = content_div.get_text("\n", strip=True) if content_div else ""

    pres_div = soup.find("div", class_="president")
    president = pres_div.get_text(strip=True) if pres_div else None

    cat_div = soup.find("div", class_="field-docs-subjects")
    category = cat_div.get_text(" ", strip=True) if cat_div else None

    return {
        "president": president,
        "date": date,
        "title": title,
        "category": category,
        "url": url,
        "transcript": transcript
    }

all_rows = []

for name, pid in PRESIDENT_IDS.items():
    print(f"Scraping {name} (ID: {pid})")
    links = get_document_links(pid)
    print(f"Found {len(links)} documents for {name}")

    for link in tqdm(links):
        try:
            data = scrape_document(link)
            all_rows.append(data)
        except Exception as e:
            print("Error on:", link, e)
        time.sleep(0.1)

df = pd.DataFrame(all_rows)
df.to_csv("APP_all_documents_updated.csv", index=False)
print("Total documents scraped:", len(df))
# Out:
# Scraping Joe Biden (ID: 35300)
# Found 0 documents for Joe Biden
# 0it [00:00, ?it/s]
# Scraping Donald J. Trump (ID: 33002)
# Found 0 documents for Donald J. Trump
# 0it [00:00, ?it/s]
# Scraping Barack Obama (ID: 27051)
# Found 0 documents for Barack Obama
# 0it [00:00, ?it/s]
# Scraping George W. Bush (ID: 23001)
# Found 0 documents for George W. Bush
# 0it [00:00, ?it/s]
# Scraping Bill Clinton (ID: 18000)
# Found 0 documents for Bill Clinton
# 0it [00:00, ?it/s]
# Total documents scraped: 0

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
import time

BASE = "https://www.presidency.ucsb.edu"

# --- CATEGORY URLs for all presidential documents ---
CATEGORY_URLS = [
    "/documents/app-categories/presidential",
    "/documents/app-categories/spoken-addresses-and-remarks/presidential",
    "/documents/app-categories/presidential/inaugural-addresses",
    "/documents/app-categories/presidential/statements",
    "/documents/app-categories/presidential/letters",
    "/documents/app-categories/presidential/executive-orders",
    "/documents/app-categories/presidential/proclamations",
    "/documents/app-categories/presidential/memoranda",
    "/documents/app-categories/presidential/news-conferences",
    # add more if needed
]

def get_document_links(category_url, max_pages=300):
    """Scrape all document links from a category, across all pages"""
    links = []
    for page in range(max_pages):
        url = f"{BASE}{category_url}?items_per_page=100&page={page}"
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")

        rows = soup.select("div.view-content .views-row a")
        if not rows:
            break

        for a in rows:
            href = a.get("href")
            if href and href.startswith("/documents/"):
                links.append(BASE + href)
        time.sleep(0.1)
    return links

def scrape_document(url):
    """Scrape a single document page"""
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    title_tag = soup.find("h1")
    title = title_tag.get_text(strip=True) if title_tag else None

    date_tag = soup.find("span", class_="date-display-single")
    date = date_tag.get_text(strip=True) if date_tag else None

    content_div = soup.find("div", class_="field-docs-content")
    transcript = content_div.get_text("\n", strip=True) if content_div else ""

    pres_div = soup.find("div", class_="president")
    president = pres_div.get_text(strip=True) if pres_div else None

    cat_div = soup.find("div", class_="field-docs-subjects")
    category = cat_div.get_text(" ", strip=True) if cat_div else None

    return {
        "president": president,
        "date": date,
        "title": title,
        "category": category,
        "url": url,
        "transcript": transcript
    }

# --- MAIN SCRAPE LOOP ---

all_rows = []

for cat_url in CATEGORY_URLS:
    print(f"Scraping category: {cat_url}")
    links = get_document_links(cat_url)
    print(f"Found {len(links)} documents in this category")

    for link in tqdm(links):
        try:
            data = scrape_document(link)
            all_rows.append(data)
        except Exception as e:
            print("Error scraping:", link, e)
        time.sleep(0.1)  # polite pause

# --- SAVE TO CSV ---
df = pd.DataFrame(all_rows)
df.to_csv("APP_all_presidential_documents.csv", index=False)
print("Scrape complete! Total documents:", len(df))
# Out:
# Scraping category: /documents/app-categories/presidential
# Found 100 documents in this category
#   0%|          | 0/100 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 82
#      80 for link in tqdm(links):
#      81     try:
# ---> 82         data = scrape_document(link)
#      83         all_rows.append(data)
#      84     except Exception as e:
#
# Cell In[26], line 44, in scrape_document(url)
#      42 def scrape_document(url):
#      43     """Scrape a single document page"""
# ---> 44     r = requests.get(url)
#      45     soup = BeautifulSoup(r.text, "html.parser")
#      47     title_tag = soup.find("h1")
#
# File c:\Users\shime\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
import time
import os

BASE = "https://www.presidency.ucsb.edu"

# --- Speech categories to scrape ---
CATEGORY_URLS = {
    "Spoken Addresses and Remarks": "/documents/app-categories/spoken-addresses-and-remarks/presidential",
    "Inaugural Addresses": "/documents/app-categories/presidential/inaugural-addresses",
    "Farewell Addresses": "/documents/app-categories/presidential/farewell-addresses",
    "State of the Union Addresses": "/documents/app-categories/presidential/state-the-union-addresses",
    "Saturday Weekly Addresses": "/documents/app-categories/presidential/saturday-weekly-addresses",
    "Fireside Chats": "/documents/app-categories/presidential/fireside-chats",
    "Convention Speeches": "/documents/app-categories/elections-and-transitions/convention-speeches",
    "News Conferences": "/documents/app-categories/presidential/news-conferences"  # optional
}

OUTPUT_FILE = "APP_speeches.csv"

# --- Load existing progress if any ---
if os.path.exists(OUTPUT_FILE):
    df_existing = pd.read_csv(OUTPUT_FILE)
    all_rows = df_existing.to_dict(orient="records")
    print(f"Loaded {len(all_rows)} previously scraped speeches.")
else:
    all_rows = []

# --- Get document links for a category ---
def get_document_links(category_url, max_pages=500):
    links = []
    for page in range(max_pages):
        url = f"{BASE}{category_url}?items_per_page=100&page={page}"
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")

        # Updated selector for current site HTML
        rows = soup.select("div.view-content h3.title a")
        if not rows:
            break

        for a in rows:
            href = a.get("href")
            if href and href.startswith("/documents/"):
                links.append(BASE + href)

        print(f"Page {page+1}: found {len(rows)} documents")
        time.sleep(0.1)  # polite scraping

    return links

# --- Scrape individual document ---
def scrape_document(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    title_tag = soup.find("h1")
    title = title_tag.get_text(strip=True) if title_tag else None

    date_tag = soup.find("span", class_="date-display-single")
    date = date_tag.get_text(strip=True) if date_tag else None

    content_div = soup.find("div", class_="field-docs-content")
    transcript = content_div.get_text("\n", strip=True) if content_div else ""

    pres_div = soup.find("div", class_="president")
    president = pres_div.get_text(strip=True) if pres_div else None

    cat_div = soup.find("div", class_="field-docs-subjects")
    category = cat_div.get_text(" ", strip=True) if cat_div else None

    return {
        "president": president,
        "date": date,
        "title": title,
        "category": category,
        "url": url,
        "transcript": transcript
    }

# --- Scrape all categories ---
for cat_name, cat_url in CATEGORY_URLS.items():
    print(f"\n--- Scraping category: {cat_name} ---")
    links = get_document_links(cat_url)
    print(f"Found {len(links)} documents in {cat_name}")

    for link in tqdm(links):
        try:
            data = scrape_document(link)
            all_rows.append(data)
        except Exception as e:
            print("Error scraping:", link, e)
        time.sleep(0.1)  # polite scraping

    # Save progress after each category
    df = pd.DataFrame(all_rows)
    df.to_csv(OUTPUT_FILE, index=False)
    print(f"Saved progress: {len(df)} speeches so far")

print("Scraping complete!")
# Out:
# --- Scraping category: Spoken Addresses and Remarks ---
# Found 0 documents in Spoken Addresses and Remarks
# 0it [00:00, ?it/s]
# Saved progress: 0 speeches so far
#
# --- Scraping category: Inaugural Addresses ---
# Found 0 documents in Inaugural Addresses
# 0it [00:00, ?it/s]
# Saved progress: 0 speeches so far
#
# --- Scraping category: Farewell Addresses ---
# Found 0 documents in Farewell Addresses
# 0it [00:00, ?it/s]
# Saved progress: 0 speeches so far
#
# --- Scraping category: State of the Union Addresses ---
# Found 0 documents in State of the Union Addresses
# 0it [00:00, ?it/s]
# Saved progress: 0 speeches so far
#
# --- Scraping category: Saturday Weekly Addresses ---
# Found 0 documents in Saturday Weekly Addresses
# 0it [00:00, ?it/s]
# Saved progress: 0 speeches so far
#
# --- Scraping category: Fireside Chats ---
# Found 0 documents in Fireside Chats
# 0it [00:00, ?it/s]
# Saved progress: 0 speeches so far
#
# --- Scraping category: Convention Speeches ---
# ...

# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

BASE_URL = "https://www.presidency.ucsb.edu"
CATEGORY_URL = "/documents/app-categories/presidential/spoken-addresses-and-remarks"
OUTPUT_FILE = "spoken_addresses.csv"

def get_documents_from_page(url):
    """Scrape all documents on a single page"""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    rows = soup.select("div.node-documents.node-teaser")
    documents = []

    for row in rows:
        title_tag = row.select_one("div.field-title a")
        date_tag = row.select_one("h4 span.date-display-single")
        president_tag = row.select_one("div.col-sm-4 p a")
        
        if title_tag and date_tag and president_tag:
            title = title_tag.text.strip()
            link = BASE_URL + title_tag["href"]
            date = date_tag["content"]  # ISO format
            president = president_tag.text.strip()
            documents.append({
                "title": title,
                "link": link,
                "date": date,
                "president": president
            })
    return documents

def scrape_all_documents():
    all_docs = []
    page = 0

    while True:
        print(f"Scraping page {page+1}")
        url = f"{BASE_URL}{CATEGORY_URL}?page={page}"
        docs = get_documents_from_page(url)
        
        if not docs:  # No more documents
            break
        
        all_docs.extend(docs)
        page += 1
        
        # Be polite
        time.sleep(1)

    # Save to CSV
    keys = ["title", "link", "date", "president"]
    with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=keys)
        writer.writeheader()
        writer.writerows(all_docs)
    
    print(f"Scraping complete! {len(all_docs)} documents saved to {OUTPUT_FILE}")

if __name__ == "__main__":
    scrape_all_documents()
# Out:
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5
# Scraping page 6
# Scraping page 7
# Scraping page 8
# Scraping page 9
# Scraping page 10
# Scraping page 11
# Scraping page 12
# Scraping page 13
# Scraping page 14
# Scraping page 15
# Scraping page 16
# Scraping page 17
# Scraping page 18
# Scraping page 19
# Scraping page 20
# Scraping page 21
# Scraping page 22
# Scraping page 23
# Scraping page 24
# Scraping page 25
# Scraping page 26
# Scraping page 27
# Scraping page 28
# Scraping page 29
# Scraping page 30
# Scraping page 31
# Scraping page 32
# Scraping page 33
# Scraping page 34
# Scraping page 35
# Scraping page 36
# Scraping page 37
# Scraping page 38
# Scraping page 39
# Scraping page 40
# Scraping page 41
# Scraping page 42
# Scraping page 43
# Scraping page 44
# Scraping page 45
# Scraping page 46
# ---------------------------------------------------------------------------
# ...

# %%
BASE_URL = "https://www.presidency.ucsb.edu"
CATEGORY_URL = "/documents/app-categories/presidential/spoken-addresses-and-remarks"
OUTPUT_FILE = "spoken_addresses.csv"

def get_documents_from_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    rows = soup.select("div.node-documents.node-teaser")
    documents = []

    for row in rows:
        title_tag = row.select_one("div.field-title a")
        date_tag = row.select_one("h4 span.date-display-single")
        president_tag = row.select_one("div.col-sm-4 p a")
        
        if title_tag and date_tag and president_tag:
            title = title_tag.text.strip()
            link = BASE_URL + title_tag["href"]
            date = date_tag["content"]
            president = president_tag.text.strip()
            documents.append({
                "title": title,
                "link": link,
                "date": date,
                "president": president
            })
    return documents

def scrape_all_documents():
    keys = ["title", "link", "date", "president"]
    page = 0
    total_docs = 0

    # Open CSV once for streaming results
    with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=keys)
        writer.writeheader()

        while True:
            url = f"{BASE_URL}{CATEGORY_URL}?page={page}"
            docs = get_documents_from_page(url)
            
            if not docs:
                break  # No more documents
            
            for doc in docs:
                writer.writerow(doc)
            
            total_docs += len(docs)
            print(f"Scraped page {page+1}: {len(docs)} documents (Total: {total_docs})")
            
            page += 1
            time.sleep(1)  # Be polite to server

    print(f"Scraping complete! Total documents saved: {total_docs}")

if __name__ == "__main__":
    scrape_all_documents()
# Out:
# Scraped page 1: 10 documents (Total: 10)
# Scraped page 2: 10 documents (Total: 20)
# Scraped page 3: 10 documents (Total: 30)
# Scraped page 4: 10 documents (Total: 40)
# Scraped page 5: 10 documents (Total: 50)
# Scraped page 6: 10 documents (Total: 60)
# Scraped page 7: 10 documents (Total: 70)
# Scraped page 8: 10 documents (Total: 80)
# Scraped page 9: 10 documents (Total: 90)
# Scraped page 10: 10 documents (Total: 100)
# Scraped page 11: 10 documents (Total: 110)
# Scraped page 12: 10 documents (Total: 120)
# Scraped page 13: 10 documents (Total: 130)
# Scraped page 14: 10 documents (Total: 140)
# Scraped page 15: 10 documents (Total: 150)
# Scraped page 16: 10 documents (Total: 160)
# Scraped page 17: 10 documents (Total: 170)
# Scraped page 18: 10 documents (Total: 180)
# Scraped page 19: 10 documents (Total: 190)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
from pathlib import Path

BASE_URL = "https://www.presidency.ucsb.edu"
LIST_PATH = "/documents/app-categories/statements"
LIST_URL = BASE_URL + LIST_PATH
OUTFILE = "presidential_statements.csv"
HEADERS = {"User-Agent": "Mozilla/5.0 (compatible; Scraper/1.0)"}
TEMP_SAVE_EVERY = 100   # flush every N records
DELAY_BETWEEN_REQUESTS = 0.35

def fetch(url, timeout=15, tries=3):
    for attempt in range(tries):
        try:
            resp = requests.get(url, headers=HEADERS, timeout=timeout)
            resp.raise_for_status()
            return resp
        except Exception as e:
            print(f"Fetch error ({attempt+1}/{tries}) for {url}: {e}")
            time.sleep(1)
    return None

def extract_detail_content(detail_url):
    r = fetch(detail_url)
    if not r:
        return "", "", ""
    s = BeautifulSoup(r.text, "html.parser")
    content_node = s.select_one("div.field-docs-content")
    content = content_node.get_text("\n", strip=True) if content_node else ""

    # categories (if present)
    cats = s.select("div.group-meta a, div.field-ds-filed-under- a, .field-ds-filed-under a")
    categories = ", ".join([c.get_text(strip=True) for c in cats]) if cats else ""

    # citation
    cit = s.select_one(".field-prez-document-citation, .ucsbapp_citation")
    citation = cit.get_text(" ", strip=True) if cit else ""

    return content, categories, citation

def read_existing_urls(outfile):
    p = Path(outfile)
    if not p.exists():
        return set()
    try:
        with p.open("r", encoding="utf-8", newline="") as f:
            reader = csv.DictReader(f)
            return {row.get("url","").strip() for row in reader if row.get("url")}
    except Exception as e:
        print("Error reading existing CSV, will start fresh:", e)
        return set()

def scrape_statements(max_pages=None):
    existing_urls = read_existing_urls(OUTFILE)
    page = 0
    total_saved = 0

    # prepare CSV writer (append mode)
    headers = ["title", "url", "president", "date", "content", "categories", "citation"]
    outfile_path = Path(OUTFILE)
    write_header = not outfile_path.exists()

    csvfile = open(outfile_path, "a", newline="", encoding="utf-8")
    writer = csv.DictWriter(csvfile, fieldnames=headers)
    if write_header:
        writer.writeheader()

    try:
        while True:
            if max_pages is not None and page >= max_pages:
                print("Reached max_pages limit, stopping.")
                break

            page_url = f"{LIST_URL}?page={page}"
            resp = fetch(page_url)
            if not resp:
                print("Failed to fetch listing page:", page_url)
                break

            soup = BeautifulSoup(resp.text, "html.parser")

            # listing item containers for statements
            items = soup.select("div.views-row, div.node-teaser, div.node-documents.node-teaser")
            # filter duplicates and ensure items have a link
            items = [it for it in items if it.select_one("a[href*='/documents/']")]

            if not items:
                print(f"No items found on page {page}. Stopping.")
                break

            num_items = len(items)
            print(f"Scraping page {page+1}: {num_items} statements (Total so far: {total_saved + num_items})")

            for item in items:
                # Title + link
                title_a = item.select_one(".field-title a, h3 a, a[href*='/documents/']")
                if not title_a:
                    print("Skipping item (no title link). snippet:", item.get_text(" ", strip=True)[:150])
                    continue
                title = title_a.get_text(strip=True)
                href = title_a.get("href", "").strip()
                full_link = href if href.startswith("http") else BASE_URL + href

                # skip if already scraped
                if full_link in existing_urls:
                    # print("Skipping already-saved:", full_link)
                    continue

                # president (the "Related" link on the right column)
                pres_a = item.select_one(".col-sm-4 a, .views-field-field-president a, .field-title ~ .col-sm-4 a")
                president = pres_a.get_text(strip=True) if pres_a else ""

                # date
                date_span = item.select_one("span.date-display-single, .views-field-field-docs-date span, .views-field-created span")
                date = date_span.get("content", date_span.get_text(strip=True)) if date_span else ""

                # fetch detail content
                content, categories, citation = extract_detail_content(full_link)

                row = {
                    "title": title,
                    "url": full_link,
                    "president": president,
                    "date": date,
                    "content": content,
                    "categories": categories,
                    "citation": citation
                }

                writer.writerow(row)
                existing_urls.add(full_link)
                total_saved += 1

                if total_saved % TEMP_SAVE_EVERY == 0:
                    csvfile.flush()
                    print(f"Checkpoint: saved {total_saved} records so far.")

                time.sleep(DELAY_BETWEEN_REQUESTS)

            page += 1
            # small delay between pages
            time.sleep(0.5)

    finally:
        csvfile.close()

    print("Finished. Total new records saved:", total_saved)
    return total_saved

if __name__ == "__main__":
    # For a quick test set max_pages=2
    # For full run use max_pages=None
    scrape_statements(max_pages=None)
# Out:
# Scraping page 1: 20 statements (Total so far: 20)
# Scraping page 2: 20 statements (Total so far: 20)
# Scraping page 3: 20 statements (Total so far: 20)
# Scraping page 4: 20 statements (Total so far: 30)
# Scraping page 5: 20 statements (Total so far: 40)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 156
#     151     return total_saved
#     153 if __name__ == "__main__":
#     154     # For a quick test set max_pages=2
#     155     # For full run use max_pages=None
# --> 156     scrape_statements(max_pages=None)
#
# Cell In[6], line 121, in scrape_statements(max_pages)
#     118 date = date_span.get("content", date_span.get_text(strip=True)) if date_span else ""
#     120 # fetch detail content
# --> 121 content, categories, citation = extract_detail_content(full_link)
#     123 row = {
#     124     "title": title,
#     125     "url": full_link,
# ...

# %%
import pandas as pd

df = pd.read_csv("presidential_statements.csv")
print(df.shape)
df.head()


print(df['content'][1])
# Out:
# (20, 7)
# ...

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\shime\\miniconda3ins\\python.exe'
